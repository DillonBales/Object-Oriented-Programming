# %% [markdown]
# ###**Class Attributes:**

# %%
class Dog:
    species = "Canine"  # Class attribute shared by all instances

    def __init__(self, name, age):
        self.name = name
        self.age = age

# Accessing the class attribute
print(Dog.species)  # Output: Canine

# Creating instances
dog1 = Dog("Buddy", 3)
dog2 = Dog("Max", 5)

# Accessing class attribute through instances
print(dog1.species)  # Output: Canine
print(dog2.species)  # Output: Canine
# Out:
# Canine
# Canine
# Canine

# %% [markdown]
# ###**Methods**

# %%
class Dog:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def bark(self):
        print("Woof!")

    def introduce(self):
        print(f"My name is {self.name} and I am {self.age} years old.")

# Creating an instance
dog1 = Dog("Buddy", 3)

# Calling methods
dog1.bark()         # Output: Woof!
dog1.introduce()    # Output: My name is Buddy and I am 3 years old.
# Out:
# Woof!
# My name is Buddy and I am 3 years old.

# %% [markdown]
# ###**Instance Methods vs. Class Methods:**

# %% [markdown]
# ###**Instance Methods:**
#   Instance methods operate on an instance of the class and have access to instance-specific attributes. They are defined using the self parameter.
# ###**Class Methods:**
#   Class methods operate on the class itself and have access to class attributes. They are defined using the @classmethod decorator and have access to the class (via 'cls' parameter).

# %%
class MyClass:
    class_attribute = "Class attribute"

    def __init__(self, instance_attribute):
        self.instance_attribute = instance_attribute

    def instance_method(self):
        print(f"Instance method called with {self.instance_attribute}")

    @classmethod
    def class_method(cls):
        print(f"Class method called with {cls.class_attribute}")

# Creating an instance
obj = MyClass("Instance attribute")

# Calling instance method
obj.instance_method()  # Output: Instance method called with Instance attribute

# Calling class method
MyClass.class_method()  # Output: Class method called with Class attribute
# Out:
# Instance method called with Instance attribute
# Class method called with Class attribute
