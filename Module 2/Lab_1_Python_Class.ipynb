# %% [markdown]
# # **Lab 1 Python Class**
# # Total Points 100
# #### Problem 1: Class Creation
#
# 1. Create a class named `Car` with the following attributes:
#    - `brand` (string)
#    - `model` (string)
#    - `year` (integer)
#    - `mileage` (float)
#
# #### Problem 2: Object Instantiation
#
# 2. Instantiate three objects of the `Car` class with different values for the attributes.
#
# #### Problem 3: Method Implementation
#
# 3. Add a method named `display_info` to the `Car` class that prints information about the car, including brand, model, year, and mileage.
#
# #### Problem 4: Inheritance
#
# 4. Create a new class named `ElectricCar` that inherits from the `Car` class. Add a new attribute `battery_capacity` (integer) to the `ElectricCar` class.
#
# #### Problem 5: Method Override
#
# 5. Override the `display_info` method in the `ElectricCar` class to include information about the battery capacity.
#
# #### Problem 6: Object Instantiation (ElectricCar)
#
# 6. Instantiate two objects of the `ElectricCar` class, providing values for all attributes, including the new `battery_capacity` attribute.
#
# #### Problem 7: Testing
#
# 7. Create instances of both the `Car` and `ElectricCar` classes and test the functionality of the `display_info` method.
#
# #### Problem 8: Additional Features (Optional)
#
# 8. Add any additional features to the classes that you think would enhance their functionality. This could include methods for updating mileage, checking battery status, etc.
#
# #### Submission
#
# Submit a Python script or Jupyter notebook containing the implementation of the classes and the testing code. Include comments to explain the purpose of each class, method, and any significant code block.
#
# **Note:** Ensure good code readability and documentation throughout your implementation.
